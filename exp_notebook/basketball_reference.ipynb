# %%
from data.get_basketball_reference import get_active_players, get_available_years, get_game_logs_from_path, get_game_logs_all

df = get_active_players()
for index, row in df.iterrows():
    if index > 49 and index < 150:
        years_path = get_available_years(row["player_url"])
        print(index)
        print(row["player"])
        table = get_game_logs_all(row["player"], years_path)
# Out:
# 50
# RJ Barrett
# 51
# Will Barton
# 52
# Paris Bass
# 53
# Charles Bassey
# 54
# Keita Bates-Diop
# 55
# Nicolas Batum
# 56
# Aron Baynes
# 57
# Kent Bazemore
# 58
# Darius Bazley
# 59
# Bradley Beal
# 60
# Malik Beasley
# 61
# Michael Beasley
# 62
# MarJon Beauchamp
# 63
# Jordan Bell
# 64
# DeAndre' Bembry
# 65
# Dragan Bender
# 66
# Dairis Bertāns
# 67
# Dāvis Bertāns
# 68
# Patrick Beverley
# 69
# Saddiq Bey
# 70
# Tyler Bey
# 71
# Khem Birch
# 72
# Goga Bitadze
# 73
# Bismack Biyombo
# 74
# Nemanja Bjelica
# 75
# Antonio Blakeney
# 76
# Eric Bledsoe
# 77
# Keljin Blevins
# 78
# Jaron Blossomgame
# 79
# Buddy Boeheim
# 80
# Bogdan Bogdanović
# 81
# Bojan Bogdanović
# 82
# Bol Bol
# 83
# Jonah Bolden
# 84
# Marques Bolden
# 85
# Leandro Bolmaro
# 86
# Jordan Bone
# 87
# Isaac Bonga
# 88
# Devin Booker
# 89
# Brandon Boston Jr.
# 90
# Chris Boucher
# 91
# James Bouknight
# 92
# Brian Bowen
# 93
# Ky Bowman
# 94
# Avery Bradley
# 95
# Tony Bradley
# 96
# Malaki Branham
# 97
# ...
